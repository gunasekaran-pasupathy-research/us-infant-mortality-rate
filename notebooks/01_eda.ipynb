# %% [markdown]
# # 01 — Exploratory Data Analysis
#
# Load the CDC infant-mortality series and look at the long-run trend by race.
#
# **Input**: CDC API (auto-pulled and cached to `data/raw/`)

# %%
# add the project folder to the path so we can import our code in src/
import sys
from pathlib import Path
sys.path.insert(0, str(Path.cwd().parent))

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from src.data.load import load_raw
from src.viz.plots import plot_trend
from src.config import RATE_COL

sns.set_theme()

# %%
# pull the data (downloads from the CDC API the first time, then reads the local copy)
df = load_raw()
print(df.shape)
df.head()

# %%
# how is the rate distributed, and what does each column look like?
df.info()
df[RATE_COL].describe()

# %%
# the headline picture: infant mortality over time, one line per race
plot_trend(df)
plt.show()

# %% [markdown]
# ## Notes
#
# - The rate falls steeply over the century for both groups.
# - Watch for the two spellings of 'Black' in the raw data - cleaned up in notebook 02.
# - The decline looks roughly exponential, which motivates a log scale in notebook 04.
