# %% [markdown]
# # 01 — Exploratory Data Analysis (CDC, by race)
#
# Start with the CDC/NCHS U.S. series and look at the long-run trend by race.
#
# **Input**: CDC API (auto-pulled and cached to `data/raw/`)

# %%
# add the project folder to the path so we can import our code in src/
import sys
from pathlib import Path
sys.path.insert(0, str(Path.cwd().parent))

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from src.data.sources import cdc
from src.viz.plots import plot_trend

sns.set_theme()

# %%
# tidy CDC data: one row per race-year, columns = source, entity, iso3, year, imr, ...
df = cdc.tidy()
print(df.shape)
df.head()

# %%
# how is the rate distributed?
df['imr'].describe()

# %%
# the headline: infant mortality over time, one line per race
plot_trend(df, title='U.S. infant mortality by race, 1915–2013')
plt.show()

# %% [markdown]
# ## Notes
#
# - Steep decline for both groups; the decline looks roughly exponential.
# - Other data sources (World Bank, WHO, OWID, UN IGME) are added in notebook 05.
